# %% [markdown]
# # EV Purchase Intention Notebook
#
# 这是一个入口页。为避免语言版本和结果版本分叉，请打开下面两个结果报告之一：
#
# - [中文结果报告](01_ev_purchase_intention_zh.ipynb)
# - [English results report](01_ev_purchase_intention_en.ipynb)
#
# 两个版本均读取统一 pipeline 的已保存结果，不再保留旧版的手工 Q22 定义、单次 train/test split 或独立随机森林流程。
#
# This is a navigation notebook. Use the Chinese or English report above; both read the shared pipeline artifacts.
