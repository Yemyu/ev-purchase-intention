# %% [markdown]
# # EV Purchase Intention
#
# - [中文研究报告](01_ev_purchase_intention_zh.ipynb)
# - [English research report](01_ev_purchase_intention_en.ipynb)
#
# 两个语言版本包含同一次分析的表格、图片与结果说明。
# Both language versions include tables, figures and commentary from the same analysis run.
